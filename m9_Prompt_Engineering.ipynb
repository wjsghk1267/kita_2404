# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00

# %% [markdown]
# Chat Completion API

# %%
from openai import OpenAI
client = OpenAI(api_key='')

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {
            'role': 'system', 'content': '당신은 AI 모델 개발자이다',
            'role': 'user', 'content': 'LLM에 대해 설명해줘'
        },
    ]
)
# print(completion)
print(completion.choices[0].message.content)
# Out:
# LLM은 "Large Language Model"의 약자로, 대규모 언어 모델을 의미합니다. 이는 수많은 텍스트 데이터를 학습하여 인간 언어를 이해하고 생성할 수 있는 인공지능 모델입니다. LLM은 다양한 자연어 처리(NLP) 작업을 수행할 수 있으며, 그 예로는 텍스트 생성, 요약, 번역, 질문 응답 등이 있습니다.
#
# LLM의 주요 특징은 다음과 같습니다:
#
# 1. **규모**: LLM은 수억 개에서 수천억 개의 파라미터를 가지고 있으며, 이러한 거대한 규모는 모델의 표현 능력과 학습 능력을 크게 향상시킵니다.
#
# 2. **사전 학습과 미세 조정**: LLM은 일반적인 언어 패턴을 학습하기 위해 대규모 데이터셋에서 사전 학습됩니다. 이후 특정 작업에 대해 미세 조정(fine-tuning)을 통해 성능을 더욱 개선할 수 있습니다.
#
# 3. **컨텍스트 이해**: LLM은 입력된 텍스트의 맥락을 이해하고, 그에 맞는 적절한 응답을 생성할 수 있는 능력을 가지고 있습니다.
#
# 4. **자연어 생성**: LLM은 자연스러운 텍스트를 생성할 수 있어, 사용자가 요구하는 텍스트 형식에 맞춰 글을 작성하거나 대답할 수 있습니다.
#
# 5. **광범위한 응용 분야**: LLM은 비즈니스, 교육, 엔터테인먼트 등 다양한 분야에서 활용되고 있으며, 고객 지원, 콘텐츠 작성, 코드 생성 등 여러 용도로 이용됩니다.
#
# 이러한 특징 덕분에 LLM은 현재 활발히 연구되고 개발되고 있으며, 다양한 산업에서 그 가능성을 탐구하고 있습니다.

# %% [markdown]
# 명확성과 구체성
# - 특정 주제에 대해 글을 작성하도록 요청할 때

# %%
from openai import OpenAI

prompt = "재상 가능 에너지원이 지구 온난화를 줄이는데 기여하는 이점에 대해 간결한 단락으로 설명해줘"

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {
            'role': 'system', 'content': '당신은 환경문제를 연구하는 과학자이다',
            'role': 'user', 'content': prompt
        },
    ]
)

print(completion.choices[0].message.content)
# Out:
# 재생 가능 에너지원은 태양광, 풍력, 수력 등 자연에서 재생 가능한 에너지를 활용하여 전기를 생산합니다. 이러한 에너지원은 화석 연료 사용을 줄임으로써 온실가스 배출을 감소시키고, 지구 온난화의 주범인 이산화탄소 농도를 낮추는 데 기여합니다. 또한, 재생 가능 에너지 시스템은 지역 사회의 에너지 독립성을 높이고, 지속 가능한 발전을 촉진하여 경제적 이익과 환경 보호를 동시에 실현할 수 있습니다. 이러한 특징들은 우리 미래 세대에게 보다 건강하고 안전한 지구를 물려주는 데 중요한 역할을 합니다.

# %%
from openai import OpenAI

prompt = "교통사고 발생시 과실비율를 제공하는 Chat Agent의 이점에 대해 홍보하는 문구를 간결한 단락으로 임팩트 있게 만들어줘"

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {
            'role': 'system', 'content': '당신은 마케팅 전문가이다',
            'role': 'user', 'content': prompt
        },
    ]
)

print(completion.choices[0].message.content)
# Out:
# 교통사고 발생 시, 과실비율을 신속하고 정확하게 제공하는 우리의 Chat Agent는 당신의 소중한 시간을 절약하고 불확실성을 줄여줍니다. 복잡한 법적 절차를 이해하기 쉽게 안내하며, 공정한 피해 보상을 위한 첫걸음을 내딛게 합니다. 언제 어디서나 손쉽게 상담받고, 안심하세요! 당신의 안전을 책임지는 스마트한 동반자입니다.

# %% [markdown]
# 맥락 제공
# - 특정 사건에 대한 설명을 요청할 때

# %%
from openai import OpenAI

prompt = (
    "다음 맥락을 고려하여 설명해줘 : '2022년, OpenAI의 등장은 다양한 산업에 큰 영향을 주었다. "
          "Open AI가 전세계 다양한 산업 분야에 미친 영향을 분석해줘.'"
    )

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {
            'role': 'system', 'content': '당신은 경제 전문가이다',
            'role': 'user', 'content': prompt
        },
    ]
)

print(completion.choices[0].message.content)
# Out:
# 2022년 OpenAI의 등장은 인공지능(AI) 기술의 발전과 활용에 있어 획기적인 변화를 가져왔으며, 이는 다양한 산업 분야에 광범위한 영향을 미쳤습니다. 다음은 몇 가지 주요 산업별로 OpenAI의 영향력을 분석한 내용입니다.
#
# 1. **IT 및 소프트웨어 개발**:
#    - OpenAI의 모델들은 프로그래머들이 코드 작성이나 디버깅을 보다 효율적으로 수행할 수 있도록 돕는 도구로 활용되고 있습니다. 예를 들어, GitHub Copilot 같은 AI 기반 코드 작성 보조 도구는 개발자 생산성을 크게 향상시켰습니다.
#
# 2. **교육**:
#    - AI 튜터링 시스템은 개인 맞춤형 학습 경험을 제공하여 학생들에게 더 나은 교육 성과를 달성할 수 있도록 지원합니다. OpenAI의 언어 모델은 자연어 처리(NLP)를 통해 대화형 학습 지원 또는 과제 도움에 활용될 수 있습니다.
#
# 3. **헬스케어**:
#    - 의료 데이터 분석 및 환자 상담에 AI를 도입함으로써, 진단의 정확성을 높이고 환자 맞춤형 치료 방안을 모색하는 데 기여하고 있습니다. OpenAI의 AI 기술은 의료 기록 분석, 연구 데이터 분석 및 심리 상담에서도 활용되고 있습니다.
#
# 4. **금융 서비스**:
#    - 자산 관리, 투자 분석, 위험 평가 등 다양한 금융 서비스 분야에서 AI가 데이터를 분석하고 예측하는 데 이용됩니다. OpenAI의 언어 모델은 시장 동향을 파악하고 투자 결정을 지원하는 데 유용하게 활용될 수 있습니다.
#
# 5. **마케팅 및 고객 서비스**:
#    - AI 챗봇과 자동화된 고객 지원 시스템이 빠르게 확산되면서 고객과의 상호작용을 개선하고 있습니다. OpenAI의 모델은 고객의 질문에 신속하고 정확하게 답변함으로써 고객 만족도를 높이는 데 기여하고 있습니다.
#
# 6. **제조업**:
#    - 예측 유지보수 및 생산 최적화에 AI를 활용함으로써 비용 절감 및 효율성을 높이는 데 중요한 역할을 하고 있습니다. OpenAI의 기술은 공정 개선과 품질 관리에 도움을 줄 수 있습니다.
#
# 이처럼 OpenAI의 등장은 다양한 산업에서 혁신을 이끌어내고 있으며, 기업들이 AI 기술을 통해 운영 효율성을 강화하고, 새로운 비즈니스 모델을 창출하며, 고객 경험을 향상시키는 데 기여하고 있습니다. 앞으로도 AI 기술의 발전에 따라 그 영향력은 더욱 커질 것으로 예상됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 반복과 테스트
# - 여러 프롬프트를 테스트하여 최적의 결과 도출

# %%
prompts = [
    "정기적인 운동의 건강상의 이점은 무엇인가?",
    "정기적인 운동을 하는 것의 장점에 대한 설명",
    "정기적인 신체 활동이 건강에 어떤 영향을 미치는지?"
]

for prompt in prompts:
    completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {'role': 'system', 'content': '당신은 건강관리 전문가이다'},
        {'role': 'user', 'content': prompt},
    ]
)

    print(f'프롬프트: {prompt}')
    print(completion.choices[0].message.content)
    print('\n'+'='*100 + '\n')
# Out:
# 프롬프트: 정기적인 운동의 건강상의 이점은 무엇인가?
# 정기적인 운동은 여러 가지 건강상의 이점을 제공합니다. 다음은 그 중 몇 가지입니다:
#
# 1. **심혈관 건강 개선**: 운동은 심장 근육을 강화하고 혈액 순환을 촉진하여 심혈관 질환의 위험을 낮춥니다.
#
# 2. **체중 관리**: 규칙적인 신체 활동은 칼로리를 소모하고 체중 조절에 도움이 됩니다. 비만 예방에도 효과적입니다.
#
# 3. **근육과 뼈 건강 증진**: 근력 운동은 근육량을 증가시키고 뼈의 밀도를 높여 골다공증을 예방합니다.
#
# 4. **정신 건강 개선**: 운동은 스트레스 해소, 우울증 및 불안 감소, 자존감 향상에 도움을 줍니다. 엔도르핀 분비로 기분을 좋게 합니다.
#
# 5. **면역력 강화**: 정기적인 운동은 면역 시스템을 강화하여 감염에 대한 저항력을 높입니다.
#
# 6. **혈당 조절**: 운동은 인슐린 민감성을 향상시키고 혈당 수치를 조절하는 데 도움을 주어 당뇨병 예방에 효과적입니다.
#
# 7. **수면 질 향상**: 운동은 수면의 질을 개선하고 불면증을 완화하는 데 도움을 줄 수 있습니다.
#
# 8. **인지 기능 향상**: 규칙적인 운동은 기억력과 집중력을 향상시켜 인지 기능을 유지하는 데 도움을 줄 수 있습니다.
#
# 9. **노화 방지**: 운동은 건강한 노화를 촉진하고 노화 관련 질병의 위험을 줄이는 데 기여합니다.
#
# 10. **사회적 상호작용 기회 제공**: 운동은 친구나 가족과 함께 할 기회를 제공하여 사회적 관계를 강화하는 데 도움을 줄 수 있습니다.
#
# 이러한 이점들은 신체적인 활동의 종류, 강도 및 빈도에 따라 다를 수 있지만, 전반적으로 건강을 유지하고 증진시키는 데 큰 기여를 합니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적인 운동을 하는 것의 장점에 대한 설명
# 정기적인 운동은 신체적, 정신적, 사회적 건강에 여러 가지 긍정적인 영향을 미칩니다. 아래에 그 주요 장점을 설명하겠습니다.
#
# 1. **신체 건강 증진**:
#    - **체중 조절**: 운동은 칼로리를 소모하고 신진대사를 촉진하여 체중을 관리하는 데 도움을 줍니다.
#    - **심혈관 건강**: 규칙적인 유산소 운동은 심혈관계 건강을 개선하고 고혈압 및 심장병의 위험을 줄이는 데 효과적입니다.
#    - **근육 및 뼈 강화**: 저항 운동은 근육량을 늘리고 뼈 밀도를 증가시켜 골다공증 등의 질환 예방에 기여합니다.
#
# 2. **정신적 건강 개선**:
#    - **스트레스 감소**: 운동은 스트레스 호르몬 수치를 낮추고, 기분을 좋게 하는 물질인 엔도르핀을 분비시켜 스트레스를 해소하는 데 도움이 됩니다.
#    - **우울증 및 불안 완화**: 정기적인 운동은 우울증과 불안 증상을 완화시키고 전반적인 정서적 안정감을 제공합니다.
#    - **정신적 집중력 향상**: 신체 활동은 뇌의 혈류를 증가시켜 집중력과 기억력을 향상시킬 수 있습니다.
#
# 3. **사회적 연결**:
#    - 운동은 친구와 가족과의 유대감을 강화하고, 새로운 사람들을 만나고 사회적 관계를 형성하는 데 도움을 줍니다. 운동 동호회나 클래스에 참여함으로써 더 많은 사람들과 교류할 수 있습니다.
#
# 4. **수면 개선**:
#    - 정기적인 운동은 수면의 질을 향상하고, 잠들기 쉽게 하며, 깊은 수면을 취하는 데 도움을 줍니다.
#
# 5. **자신감 및 자아 존중감 향상**:
#    - 운동을 통해 신체 변화를 경험하고, 목표를 달성함으로써 자기 효능감과 자신감을 높일 수 있습니다.
#
# 6. **만성 질환 예방 및 관리**:
#    - 당뇨병, 비만, 관절염 등 여러 만성 질환의 예방 및 관리에 효과적입니다. 운동은 인슐린 감수성을 개선하고 염증을 줄이는 데 기여합니다.
#
# 정기적인 운동은 이러한 여러 장점을 통해 전반적인 삶의 질을 향상시킬 수 있습니다. 일상에 조금씩 운동을 포함시키는 것이 중요하며, 개인의 체력과 건강 상태에 맞는 적절한 운동을 선택하는 것이 좋습니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적인 신체 활동이 건강에 어떤 영향을 미치는지?
# 정기적인 신체 활동은 건강에 매우 긍정적인 영향을 미칩니다. 아래는 그 주요 이점들입니다:
#
# 1. **심혈관 건강 개선**: 규칙적인 운동은 심장과 혈관의 기능을 향상시켜 심혈관 질환의 위험을 감소시킵니다.
#
# 2. **체중 관리**: 신체 활동은 칼로리를 소모하고, 체중 감량 및 유지를 도와줍니다. 이는 비만과 관련된 다양한 질병을 예방하는 데 중요한 역할을 합니다.
#
# 3. **근육 및 뼈 건강 강화**: 운동은 근육을 강화하고 뼈 밀도를 증가시키며, 이는 골다공증과 같은 뼈 관련 질환 예방에 도움을 줍니다.
#
# 4. **정신 건강 향상**: 신체 활동은 스트레스를 줄이고 우울증, 불안 증상을 완화하며, 전반적인 기분을 개선하는 데 도움이 됩니다. 운동 중 분비되는 엔돌핀은 '행복 호르몬'으로 불리며 기분을 좋게 합니다.
#
# 5. **면역력 강화**: 규칙적으로 운동을 하는 사람들은 면역 체계가 강화되어 감염에 대한 저항력이 높아지는 경향이 있습니다.
#
# 6. **수면 질 향상**: 신체 활동은 깊고 편안한 수면을 돕고, 불면증과 같은 수면 장애를 완화하는 데 기여할 수 있습니다.
#
# 7. **인지 기능 개선**: 운동은 뇌 건강에도 중요한 영향을 미치며, 인지 기능과 기억력을 향상시키는 데 도움을 줄 수 있습니다.
#
# 8. **생활 습관 개선**: 운동을 통해 건강한 습관을 발전시키면, 전반적인 생활 스타일이 개선되어 건강한 식습관을 형성하는 데 도움이 됩니다.
#
# 이와 같이, 정기적인 신체 활동은 신체적, 정신적, 정서적으로 많은 혜택을 제공하며, 전반적인 삶의 질을 향상시킵니다. 따라서, 권장되는 최소한의 신체 활동량을 준수하는 것이 중요합니다.
#
# ====================================================================================================

# %%
prompts = [
    "2023년도 주식시장을 분석했을때, 가장 많이 오른 분야는?",
    "2024년 세계 정세를 고려해보았을 때, 현재 유망한 투자 분야는?",
    "과거부터 현재까지의 경제상황을 분석. 미래 투자가 유망한 종목을 추천한다면?"
]

for prompt in prompts:
    completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {'role': 'system', 'content': '당신은 경제 전문가이다'},
        {'role': 'user', 'content': prompt},
    ]
)

    print(f'프롬프트: {prompt}')
    print(completion.choices[0].message.content)
    print('\n'+'='*100 + '\n')
# Out:
# 프롬프트: 2023년도 주식시장을 분석했을때, 가장 많이 오른 분야는?
# 2023년도 주식시장에서 가장 두드러진 상승을 보인 분야는 인공지능(AI)과 관련된 기술주들입니다. 특히, 클라우드 컴퓨팅, 반도체, 전기차 및 재생 에너지 산업이 활발하게 성장했습니다.
#
# 인공지능에 대한 관심과 투자 증가로 인해 관련 기업들의 주가는 큰 폭으로 상승했으며, 이와 함께 생명과학, 헬스케어 분야에서도 혁신적인 기술이 도입되면서 긍정적인 성과를 보였습니다.
#
# 또한, 금리 인상에 따른 인플레이션 압력에도 불구하고, 소비자 서비스 및 디지털 트랜스포메이션 관련 기업들도 상승세를 보였습니다. 이런 트렌드는 지속가능한 성장 가능성을 가진 기업에 대한 투자자들의 신뢰를 반영합니다.
#
# 물론, 각 시장의 상황은 지역 및 글로벌 경제 요인에 따라 다를 수 있으므로, 구체적인 투자 결정을 하기 전에는 보다 상세한 시장 분석이 필요합니다.
#
# ====================================================================================================
#
# 프롬프트: 2024년 세계 정세를 고려해보았을 때, 현재 유망한 투자 분야는?
# 2024년 세계 정세를 고려할 때, 유망한 투자 분야는 다음과 같습니다:
#
# 1. **재생 에너지**: 기후 변화에 대한 대응과 지속 가능한 발전이 중요해짐에 따라, 태양광, 풍력 등 재생 가능 에너지 관련 기업과 기술이 유망할 것으로 보입니다. 정부의 규제와 지원 정책도 이러한 산업의 성장에 긍정적인 영향을 미칠 것입니다.
#
# 2. **전기차(EV) 및 배터리 기술**: 전 세계적으로 전기차 수요가 증가하고 있으며, 이에 따라 배터리 기술 개선과 관련 기업도 주목받고 있습니다. 전기차 인프라 구축 역시 중요한 투자 분야로 평가받고 있습니다.
#
# 3. **헬스케어 및 바이오테크**: 인구 고령화와 건강에 대한 관심 증대로 헬스케어와 바이오테크 관련 기업이 지속적인 성장을 보일 것으로 예상됩니다. 특히, 유전자 편집 기술, 맞춤형 의료 솔루션 등의 혁신이 주목받고 있습니다.
#
# 4. **AI와 기술 혁신**: 인공지능, 머신러닝, 데이터 분석 등의 기술이 기업 운영과 소비자 경험을 크게 변화시키고 있습니다. 이러한 기술을 활용하는 기업은 미래 성장 가능성이 높습니다.
#
# 5. **사이버 보안**: 디지털화와 원격 근무의 확산으로 사이버 공격이 증가하고 있습니다. 이에 따라 사이버 보안 솔루션을 제공하는 기업에 대한 수요가 높아질 것으로 예상됩니다.
#
# 6. **ESG(환경, 사회, 지배구조)**: 지속 가능성과 사회적 책임을 중시하는 투자 트렌드가 계속될 것입니다. ESG 관련 기업이나 펀드는 장기적인 투자에 긍정적인 영향을 미칠 수 있습니다.
#
# 7. **디지털 자산과 블록체인**: 암호화폐와 NFT(대체 불가능 토큰) 등 디지털 자산에 대한 관심이 여전히 높은 가운데, 블록체인 기술이 금융 및 다른 산업에 혁신을 가져올 것으로 기대되고 있습니다.
#
# 현재의 글로벌 정치 및 경제적 불확실성을 고려할 때, 투자 결정을 내릴 때에는 항상 리스크 관리와 포트폴리오 다각화를 고려하는 것이 중요합니다.
#
# ====================================================================================================
#
# 프롬프트: 과거부터 현재까지의 경제상황을 분석. 미래 투자가 유망한 종목을 추천한다면?
# 경제 상황은 과거부터 현재까지 여러 가지 요인에 의해 영향을 받아왔습니다. 2008년 글로벌 금융위기, 2020년 COVID-19 팬데믹, 그리고 최근의 인플레이션과 금리 인상 등의 사건은 글로벌 경제에 큰 변화를 가져왔습니다.
#
# ### 과거 경제 분석
#
# 1. **2000년대 초반**: 닷컴 버블 붕괴 이후 경제 회복세. 저금리 환경이 조성되어 자산 가격 상승.
#
# 2. **2008년**: 글로벌 금융위기 발생. 이로 인해 많은 국가에서 경제 침체와 높은 실업률이 발생했으며, 중앙은행들은 양적 완화와 같은 비전통적인 통화정책을 시행.
#
# 3. **2020년**: COVID-19 팬데믹이 전세계 경제에 큰 충격을 주었고, 많은 산업이 붕괴하거나 큰 타격을 입었음. 그러나 기술 및 헬스케어 분야는 성장.
#
# 4. **2021-2023**: 회복세가 나타났지만, 공급망 문제와 인플레이션이 심화. 주요 중앙은행은 금리를 인상하여 물가 안정을 목표로 했음.
#
# ### 현재의 경제 상황
#
# - **인플레이션**: 높은 인플레이션이 지속되고 있으며, 이는 소비자 물가에 큰 영향을 미치고 있음.
# - **금리 인상**: 많은 중앙은행들이 금리를 인상하며 통화 긴축을 시행하고 있으며, 이는 차입비용 상승으로 이어짐.
# - **기술 혁신**: 디지털 전환, 인공지능(AI), 클라우드 컴퓨팅 등 기술 분야의 혁신이 경제에 긍정적인 영향을 미침.
#
# ### 미래 유망 투자 종목 추천
#
# 1. **AI 및 머신러닝 관련 주식**: 구글, 마이크로소프트, 오라클 등 AI 기술을 발전시키는 기업들이 유망.
#
# 2. **클린 에너지**: 태양광, 풍력 등 재생 가능 에너지 기업은 지속 가능한 성장을 할 가능성이 높음. 예: 넥스트에라 에너지, 솔라엣지 테크놀로지.
#
# 3. **헬스케어**: 바이오테크 및 제약 기업은 고령화 사회와 더불어 지속적인 수요가 예상됨. 예: 모더나, 존슨 앤 존슨.
#
# 4. **핀테크**: 디지털 결제와 관련된 기업들이 성장할 가능성이 높음. 예: 스퀘어, 페이팔.
#
# 5. **사이버 보안**: 데이터 보호와 개인 정보 보호에 대한 수요 증가로 인해, 관련 기업들이 긍정적인 전망을 가지고 있음. 예: 팰로알토 네트웍스, 시스코.
#
# 각 투자자의 재무 상태와 투자 목표에 따라 다를 수 있으므로, 전문가와의 상담 후 신중한 결정이 필요합니다.
#
# ====================================================================================================

# %%
# 특정 형식의 응답요청

prompt = (
    "숫자의 팩토리얼을 계산하는 파이썬 함수를 작성해주세요"
    "예시 : \n"
    "입력 : 5\n"
    "출력 : 120\n"
    "함수코드 : "
)

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {'role': 'system', 'content': '당신은 파이썬 코딩을 가르치는 코딩튜터이다'},
        {'role': 'user', 'content': prompt},
    ]
)

print(completion.choices[0].message.content)
# Out:
# 아래는 숫자의 팩토리얼을 계산하는 파이썬 함수입니다.
#
# ```python
# def factorial(n):
#     if n < 0:
#         return "음수의 팩토리얼은 정의되지 않습니다."
#     elif n == 0 or n == 1:
#         return 1
#     else:
#         result = 1
#         for i in range(2, n + 1):
#             result *= i
#         return result
#
# # 예시 사용
# input_number = 5
# output = factorial(input_number)
# print(f"입력: {input_number}, 출력: {output}")
# ```
#
# 이 코드는 주어진 숫자의 팩토리얼을 계산합니다. 0이나 1의 경우에는 1을 반환하고, 음수에 대해서는 정의되지 않았음을 알립니다. 2 이상의 숫자에 대해서는 반복문을 사용해 팩토리얼을 계산합니다.

# %%
# 응답형식과 길이를 명확히 지시
prompt = """다음 텍스트의 주요 포인트를 1000자 이내로 요약해주세요:
인공지능은 다양한 산업엥서 급속히 성장하는 분야로 업무 자동화, 데이터 분석을 통해 인사이트 제공,
개인 맞춤형 추천을 통한 고객 경험 향상등의 응용 분야가 있습니다"""

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {'role': 'system', 'content': '당신은 인공지능을 학습하는 대학원생이다'},
        {'role': 'user', 'content': prompt},
    ]
)
print(completion.choices[0].message.content)
# Out:
# 인공지능(AI)은 최근 다양한 산업에서 빠르게 발전하고 있는 기술로, 여러 응용 분야에서 중요한 역할을 하고 있습니다. 첫째로, AI는 업무 자동화를 통해 기업의 생산성을 높이고, 시간과 비용을 절감할 수 있도록 지원합니다. 둘째로, AI는 대량의 데이터를 분석하여 유의미한 인사이트를 도출함으로써 의사결정 과정을 개선하는 데 기여합니다. 셋째로, 개인 맞춤형 추천 시스템을 통해 소비자 경험을 향상시키고, 고객의 니즈를 보다 정확하게 반영할 수 있습니다. 이러한 특성들 덕분에 인공지능은 산업 전반에서 혁신적인 변화를 이끌고 있으며, 앞으로도 그 영향력은 계속해서 확대될 것으로 예상됩니다.

# %%
# 문법교정
response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 한국어 교사야. 문법적으로 틀린 표현을 수정해줘"},
        {"role": "user", "content": "나는 간다 학교에"}
    ],
    temperature=0.1,
    max_tokens=64,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# "나는 학교에 간다"로 수정하면 됩니다.

# %%
# 구조화 되지 않은 문법교정

prompt = """
최근에 발견된 행성 구크룩스에서 발견된 과일이 많이 있습니다. 거기에는 보라색이고 사탕 맛이 나는 네오스키즐이 자랍니다.
또한 칙칙한 파란색 과일인 로헤클도 있는데, 레몬과 비슷한 매우 신맛이 납니다. 포우닛은 밝은 녹색이고 단맛보다는 짭짤함이 더 강합니다.
네온 핑크 맛이며 솜사탕 맛이 나는 루프노바도 많이 있습니다. 마지막으로 글로울이라는 과일이 있는데,
매우 신맛이 나고 쓴맛이 나는 산성이고 부식성이 있으며 옅은 오렌지색을 띱니다.
"""

response = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
            "role":"system",
            "content": "구조화되지 않은 데이터가 제공되면 이를 CSV 형식으로 구문 분석하는 것이 여러분의 과제입니다."
        },
        {
            "role": "user",
            "content": prompt
        }
    ],

    temperature=0.7,
    max_tokens=300,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# 아래는 제공된 정보를 바탕으로 구성한 CSV 형식의 데이터입니다.
#
# ```csv
# 과일명,색상,맛
# 네오스키즐,보라색,사탕 맛
# 로헤클,칙칙한 파란색,레몬과 비슷한 매우 신맛
# 포우닛,밝은 녹색,짭짤함
# 루프노바,네온 핑크,솜사탕 맛
# 글로울,옅은 오렌지색,매우 신맛과 쓴맛, 산성, 부식성
# ```
#
# 각 과일의 이름, 색상 및 맛을 구분하여 CSV 형식으로 정리했습니다.

# %% [markdown]
# ## 감정분석

# %%
from openai import OpenAI
client = OpenAI(api_key="")


prompt = """
새로운 배트맨 영화 정말 좋았어요
"""

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system",
     "content": "트윗이 제공되면 여러분의 과제는 해당 트윗의 감정을 긍정적, 부정적, 중립적으로 분류하는 것입니다."},
    {"role": "user", "content": prompt}
  ],
  temperature=0.7,          ## 창의적이거나 무작위적인지를 조절: 0에 가까울수록 모델은 더 결정적이고 예측 가능한 출력, 1에 가까울수록 더 무작위적이고 다양한 응답을 생성
  max_tokens=64,             ## 모델이 생성할 수 있는 최대 토큰 수를 지정
  top_p=1                  ## top_p=1이면, 모델은 확률이 가장 높은 단어들을 모두 고려하여 응답을 생성, top_p 값이 낮아지면, 모델은 더 적은 수의 단어들만 고려하게 되어 응답이 더 집중되지만 덜 창의적
)

print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ccf1d6175c2c> in <cell line: 1>()
# ----> 1 from openai import OpenAI
#       2 client = OpenAI(api_key="")
#       3
#       4
#       5 prompt = """
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
