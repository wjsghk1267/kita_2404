# %%
# %pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Q1. 변수 x에 숫자 10을 할당하고, 변수 y에 문자열 "hello"를 할당한 뒤, 두 변수를 출력하세요.

# %%
x = 10
y = 'hello'
print('{}\n{}'.format(x,y))
# Out:
# 10
# hello

# %% [markdown]
# Q2. 숫자가 양수인지 음수인지를 판별하는 조건문을 작성하세요.

# %%
num1 = int(input('숫자입력 : '))

if num1 > 0 :
  print('양수')
elif num1 < 0:
   print('음수')
else:
  print('0 입니다')
# Out:
# 숫자입력 : 0
# 0 입니다

# %% [markdown]
# Q3. 리스트 [1, 2, 3, 4, 5]의 각 요소를 출력하는 반복문을 작성하세요.

# %%
numList = [1,2,3,4,5]

for i in range(5):
  print(i+1)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Q4. 두 숫자를 입력받아 더하는 함수 add를 정의하고 호출하세요.

# %%
num1 = int(input('숫자1 : '))
num2 = int(input('숫자2 : '))
addnum = num1 + num2

print('두수의 합은 : %o' %addnum)
# Out:
# 숫자1 : 5
# 숫자2 : 5
# 두수의 합은 : 12
# 7

# %% [markdown]
# Q5. 문자열 "hello"에서 처음 세 문자를 슬라이싱하여 출력하세요.

# %%
wordList = ['h','e','l','l','o']

print(wordList[0:3])
# Out:
# ['h', 'e', 'l']

# %% [markdown]
# Q6. 주어진 정수 리스트에서 가장 자주 등장하는 숫자(최빈값)를 찾아 반환하는 함수를 작성하세요. 만약 최빈값이 여러 개라면, 그 중 가장 작은 숫자를 반환하세요.
#
# numbers = [1, 3, 2, 3, 4, 1, 3, 3]

# %%
def find_mode(numbers):
  from collections import Counter
  count = Counter(numbers)
  max_freq = max(count.values())
  frequent_numbers = [num for num, freq in count.items() if freq == max_freq]
  return min(frequent_numbers)

numbers = [1,3,2,3,4,1,3,3]
print(find_mode(numbers))
# Out:
# 3

# %% [markdown]
# Q7. 딕셔너리 person에서 키 "name"의 값을 출력하세요.

# %%
person = {"name":"hong", "age":35}
print(person["name"])
# Out:
# hong

# %% [markdown]
# Q8. 이름과 나이를 입력받아 "Hello, [name]. You are [age] years old." 형식으로 출력하세요.

# %%
num1 = str(input('이름 : '))
num2 = int(input('나이 : '))

print('Hello, {}. You are {} year old'.format(num1,num2))
# Out:
# 이름 : 홍준
# 나이 : 35
# Hello, 홍준. You are 35year old

# %% [markdown]
# Q9. 0부터 9까지 숫자 중에서 홀수만 포함하는 리스트를 리스트 컴프리헨션을 사용하여 생성하세요.

# %%
dataList = [i for i in range(10) if i % 2 !=0]
print(dataList)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# Q10. 숫자를 0으로 나누려 할 때 발생하는 예외를 처리하는 코드를 작성하세요.

# %%
#num1 = int(input('숫자1 : '))
#num2 = int(input('숫자2 : '))

#divNum = num1 / num2

#if num1 != 0 and num2 != 0:
#  print(divNum)

#if num1 == 0 or num2 == 0:
#  print("0은 입력할 수 없습니다.")

num1 = int(input('숫자1 : '))
num2 = int(input('숫자2 : '))

try:
  result = (num1 / num2) % 0
except ZeroDivisionError:
  print("0으로 나눌 수 없음")
# Out:
# 숫자1 : 10
# 숫자2 : 2
# 0으로 나눌 수 없음
